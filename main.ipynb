# %% [markdown]
# ## STEP 1 — Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %% [markdown]
# ## STEP 2 — Load Dataset

# %%
df = pd.read_csv("./COVID clinical trials.csv")
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %% [markdown]
# ## STEP 3 — Basic Exploration

# %%
df.info()
df.describe(include='all')
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
# ...

# %% [markdown]
# ## STEP 4 — Drop Columns with Too Much Missing Data

# %%
df.drop(columns=['Results First Posted','Study Documents'], inplace=True, errors='ignore')

# %% [markdown]
# ## STEP 5 — Fill Missing Categorical Values

# %%
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    df[col] = df[col].fillna(f"Missing_{col}")

# %% [markdown]
# ## STEP 6 — Fill Missing Enrollment Using Median

# %%
if "Enrollment" in df.columns:
    df["Enrollment"] = df["Enrollment"].fillna(df["Enrollment"].median())

# %% [markdown]
# ## STEP 7 — Convert Dates

# %%
date_cols = ["Start Date","Primary Completion Date","Completion Date","First Posted","Last Update Posted"]
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %% [markdown]
# ## STEP 8 — Extract Country

# %%
def get_country(loc):
    if pd.isna(loc): return "Missing"
    try:
        return loc.split(",")[-1].strip()
    except:
        return "Missing"

df["Country"] = df["Locations"].apply(get_country)

# %% [markdown]
# ## STEP 9 — Simple Visualizations

# %% [markdown]
# ### A. Status of trials

# %%
plt.figure(figsize=(10,5))
df["Status"].value_counts().plot(kind="bar")
plt.title("Trial Status Distribution")
plt.show()

# %% [markdown]
# ### B.Phases distribution

# %%
plt.figure(figsize=(10,5))
df["Phases"].value_counts().plot(kind="bar")
plt.title("Phases Distribution")
plt.show()

# %% [markdown]
# ### C. Top 10 countries

# %%
df["Country"].value_counts().head(10).plot(kind="bar", figsize=(10,5))
plt.title("Top 10 Countries with Most Trials")
plt.show()

# %% [markdown]
# ### D. Trials over time

# %%
df["Start Month"] = df["Start Date"].dt.to_period("M")
df["Start Month"].value_counts().sort_index().plot(kind="line", figsize=(12,5))
plt.title("Trials Started Over Time")
plt.show()
